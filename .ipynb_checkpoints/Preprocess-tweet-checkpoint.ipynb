# %% [markdown]
# This notebook aims at merging all the shattered tweet datafiles (available at [https://crisisnlp.qcri.org/humaid_dataset.html#](https://crisisnlp.qcri.org/humaid_dataset.html#)) into one CSV file. This will come in handy for further data exploration tasks.

# %%
# Import packages
import re
import os
import numpy as np
import pandas as pd

# %%
# Select the folder list that contain information
folder_list1 = [handle for handle in os.listdir('assets/events_set1') if re.match('.*_(\d){4}',handle)]
folder_list2 = [handle for handle in os.listdir('assets/events_set2') if re.match('.*_(\d){4}',handle)]

# %%
# Aggregate all the datasets
df_train = pd.DataFrame()
df_dev = pd.DataFrame()
df_test = pd.DataFrame()

for i,folder in enumerate([folder_list1,folder_list2]):
    for filename in folder:
        search_string=re.search('(?P<place>.*)_(?P<disaster>.*)_(?P<year>.*)',filename)
        df_train_sub = pd.read_table('assets/events_set'+str(i+1)+'/'+filename+'/'+filename+'_train.tsv',delimiter = '\t',header=0)
        df_dev_sub = pd.read_table('assets/events_set'+str(i+1)+'/'+filename+'/'+filename+'_dev.tsv',delimiter = '\t',header=0)
        df_test_sub = pd.read_table('assets/events_set'+str(i+1)+'/'+filename+'/'+filename+'_dev.tsv',delimiter = '\t',header=0)
        df_train_sub['place'] = search_string['place']
        df_dev_sub['place'] = search_string['place']
        df_test_sub['place'] = search_string['place']
        df_train_sub['disaster'] = search_string['disaster']
        df_dev_sub['disaster'] = search_string['disaster']
        df_test_sub['disaster'] = search_string['disaster']
        df_train_sub['year'] = int(search_string['year'])
        df_dev_sub['year'] = int(search_string['year'])
        df_test_sub['year'] = int(search_string['year'])
        df_train = pd.concat([df_train,df_train_sub])
        df_dev = pd.concat([df_dev,df_dev_sub])
        df_test = pd.concat([df_test,df_test_sub])

# %%
# We then try to retrieve
# Out:
#                  tweet_id                                         tweet_text  \
# 3894  1031068164543721472  Kerala Govt employees this year Onam Bonus 102...
# 2374   905761715522072576  RT @RickBrundrett: Effort to fix beach damage ...
# 5693   908568086642429952  If youre rich and had hurricane damage trump w...
# 695   1039868939298373632  To everyone in areas affected by Hurricane Flo...
# 895   1112731461239664642  A picture is worth a thousand words. Even in d...
# 218   1117061318748643328  Thank you for all your contributions, whether ...
# 3431   901809440453566464  The destruction from #HurricaneHarvey &amp; #H...
# 4990  1168215222391365632  Dorian is the 4th Cat 5 storm of his presidenc...
# 302    783411688896815104  Retweeted Jared Wyand ﹎C﹎6 (@JaredWyand): Hurr...
# 1156  1113195923599974401  @realDonaldTrump You are absolutely correct --...
# 2750  1032138083645489153  Gau Seva Parishad activists stop truck carryin...
# 4769  1168005058841022464  Nah catch me buying all that Kroger water. ᾗ0ᾗ...
# 994    911982488016302080  RT @RestingPlatypus: My thoughts are with all ...
# 829    913187481054523392  PLEASE - Porto Rico - this beautiful Island an...
# 5957   907005616497053696  At least two cranes have collapsed in Miami du...
# 2758  1041439896177532928  We are a #creative agency focused on inspiring...
# 1201   906344264036229120  Long exposure of traffic on I-75 facing northb...
# 5031   908325139917537280  Numerous orgs have stepped up to accept donati...
# 470   1031048093553197057  List of dedicated Doctors for kerala flood eme...
# 490    908977899017048064  @jimmybuffett the Florida keys need your help ...
#
#                                  class_label          place    disaster  year
# 3894  rescue_volunteering_or_donation_effort         kerala      floods  2018
# 2374       infrastructure_and_utility_damage      hurricane        irma  2017
# 5693       infrastructure_and_utility_damage      hurricane        irma  2017
# 695                       caution_and_advice      hurricane    florence  2018
# 895                     sympathy_and_support  midwestern_us      floods  2019
# 218   rescue_volunteering_or_donation_effort        cyclone        idai  2019
# 3431  rescue_volunteering_or_donation_effort      hurricane      harvey  2017
# 4990                  injured_or_dead_people      hurricane      dorian  2019
# 302               other_relevant_information      hurricane     matthew  2016
# 1156                        not_humanitarian  midwestern_us      floods  2019
# 2750  rescue_volunteering_or_donation_effort         kerala      floods  2018
# 4769                        not_humanitarian      hurricane      dorian  2019
# 994                     sympathy_and_support  puebla_mexico  earthquake  2017
# 829                 requests_or_urgent_needs      hurricane       maria  2017
# 5957       infrastructure_and_utility_damage      hurricane        irma  2017
# 2758                        not_humanitarian      hurricane    florence  2018
# 1201        displaced_people_and_evacuations      hurricane        irma  2017
# 5031  rescue_volunteering_or_donation_effort      hurricane        irma  2017
# 470   rescue_volunteering_or_donation_effort         kerala      floods  2018
# 490                 requests_or_urgent_needs      hurricane        irma  2017
